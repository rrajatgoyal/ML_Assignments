# %%
#Question 1
import numpy as np
x=np.random.random((10,1))
print(np.mean(x))
# Out:
# 0.5621390124144795

# %%
#Question 2
x=np.random.random((20,1))
sd=np.std(x)
print('Standard deviation is:',sd)
v=np.var(x)
print('Variance is:',v)
# Out:
# Standard deviation is: 0.25744557940718443
# Variance is: 0.0662782263563009

# %%
#Question 3
x1=np.random.random((10,20))
x2=np.random.random((20,25))
x3=np.matmul(x1,x2)
x4=np.sum(x3)
print('Sum of new formed array elements is',x4)
print('Matrix Multiplication of x1 and x2 gives',x3)
# Out:
# Sum of new formed array elements is 1225.3488084648282
# Matrix Multiplication of x1 and x2 gives [[4.93987155 3.0862896  5.12066978 4.02326854 4.21242843 3.83963981
#   4.44790301 3.18930991 3.76397084 5.27043838 3.83279224 4.9203675
#   4.02669955 4.2434594  3.04807394 4.56376148 4.73103707 4.56913407
#   4.90402816 4.77229139 4.89945498 3.67944809 4.01512496 3.3864552
#   4.27747708]
#  [4.41350335 3.65742366 4.65997925 4.0184137  3.24743389 4.3273427
#   4.41778455 4.39605284 4.30707752 5.00629176 4.05381294 5.1598169
#   3.599951   4.37924168 4.24461936 3.70913954 5.55091649 4.94528804
#   5.15133472 4.22600463 5.51951689 4.34141298 4.32471136 3.70148029
#   3.88925245]
#  [6.61595339 5.02643284 5.8850448  5.11516326 4.85170864 6.0084071
#   6.35806319 5.70447883 5.77390796 7.49187055 5.28839079 7.19259368
#   5.62061682 5.87054801 5.46068033 5.19635437 7.42821614 6.46926301
#   6.49490949 5.93875098 7.48218827 5.61566266 5.17064157 4.99675286
#   6.17049162]
# ...

# %%
#Question
a= np.random.rand(10,1)
print(a)

def func(x):
    return (1 / (1 + np.exp(-x)))
print('*'*10)
r = np.apply_along_axis(func, 0, a)
print(r)
# Out:
# [[6.74371963e-01]
#  [2.53189591e-02]
#  [3.69780715e-01]
#  [7.11774780e-02]
#  [1.11636317e-01]
#  [6.73225013e-04]
#  [9.52376030e-01]
#  [1.62807514e-01]
#  [2.23197269e-01]
#  [4.49103788e-01]]
# **********
# [[0.66248142]
#  [0.5063294 ]
#  [0.59140599]
#  [0.51778686]
#  [0.52788013]
#  [0.50016831]
#  [0.72159277]
#  [0.54061221]
#  [0.55556882]
#  [0.61042613]]
